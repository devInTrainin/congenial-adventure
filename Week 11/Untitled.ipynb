# %%
import pandas as pd
import pyrosm as yr
from pyrosm import get_data

# %%
from pyrosm.data import sources

# Print available source categories
sources.available.keys()
# Out:
# dict_keys(['africa', 'antarctica', 'asia', 'australia_oceania', 'central_america', 'europe', 'north_america', 'south_america', 'cities', 'subregions'])

# %%
# Prints a list of countries in Africa that can be downloaded
print(sources.asia.available)
# Out:
# ['afghanistan', 'armenia', 'azerbaijan', 'bangladesh', 'bhutan', 'cambodia', 'china', 'gcc_states', 'india', 'indonesia', 'iran', 'iraq', 'israel_and_palestine', 'japan', 'jordan', 'kazakhstan', 'kyrgyzstan', 'laos', 'lebanon', 'malaysia_singapore_brunei', 'maldives', 'mongolia', 'myanmar', 'nepal', 'north_korea', 'pakistan', 'philippines', 'south_korea', 'sri_lanka', 'syria', 'taiwan', 'tajikistan', 'thailand', 'turkmenistan', 'uzbekistan', 'vietnam', 'yemen']

# %%
# Check all countries having sub-regions
print("All countries with sub-regions:", sources.subregions.available.keys())
# Out:
# All countries with sub-regions: dict_keys(['brazil', 'canada', 'france', 'germany', 'great_britain', 'italy', 'japan', 'netherlands', 'poland', 'russia', 'usa'])

# %%
# Check sub-regions in Brazil
print("Sub-regions in Brazil:", sources.subregions.netherlands.available)
# Out:
# Sub-regions in Brazil: ['drenthe', 'flevoland', 'friesland', 'gelderland', 'groningen', 'limburg', 'noord_brabant', 'noord_holland', 'overijssel', 'utrecht', 'zeeland', 'zuid_holland']

# %%
# # Download data for Aachen
# fp = get_data("cyberjaya")
# print(fp)

# %%
sources._all_sources
# Out:
# ['sucre',
#  'alsace',
#  'ural_fed_district',
#  'netherlands',
#  'zambia',
#  'huntsville',
#  'hertogenbosch',
#  'kenya',
#  'montreal',
#  'cork',
#  'cape_verde',
#  'bretagne',
#  'niger',
#  'schwerin',
#  'sudeste',
#  'seattle',
#  'providence',
#  'saint_helena_ascension_and_tristan_da_cunha',
#  'germany',
#  'utah',
#  'augsburg',
#  'morocco',
#  'cambodia',
#  'nordeste',
#  'santacruz',
#  'guinea',
#  'cook_islands',
#  'suffolk',
#  'southern_california',
#  'erlangen',
#  'louisiana',
#  'bielefeld',
#  'zachodniopomorskie',
#  'braunschweig',
#  'duesseldorf_regbez',
#  'south_africa',
#  'north_yorkshire',
#  'puerto_rico',
#  'gera',
#  'gcc_states',
#  'guyane',
#  'northwest_territories',
#  'congo_brazzaville',
#  'cusco',
#  'madagascar',
#  'leicestershire',
#  'nordrhein_westfalen',
#  'bourgogne',
#  'italy',
#  'paris',
#  'goeteborg',
#  'hampshire',
#  'stockholm',
#  'turkey',
#  'buckinghamshire',
#  'newdelhi',
#  'bremen',
#  'edinburgh',
#  'picardie',
#  'alabama',
#  'gent',
#  'australia_oceania',
#  'micronesia',
#  'canberra',
#  'baden_wuerttemberg',
#  'utrecht',
#  'tajikistan',
#  'macedonia',
#  'kiel',
#  'somalia',
#  'barcelona',
#  'volga_fed_district',
#  'vancouver',
#  'georgia',
#  'lubelskie',
#  'seoul',
#  'kazakhstan',
#  'halifax',
#  'greenland',
#  'brandenburghavel',
#  'south_sudan',
#  'virginia',
#  'west_midlands',
#  'herefordshire',
#  'cornwall',
#  'muenster',
#  'eugene',
#  'hertfordshire',
#  'innsbruck',
#  'cyprus',
#  'new_zealand',
#  'goettingen',
#  'madrid',
#  'chicago',
#  'adelaide',
#  'martinique',
#  'gelderland',
#  'ljubljana',
#  'cambridgema',
#  'wuppertal',
#  'hawaii',
#  'toulouse',
#  'limburg',
#  'montevideo',
#  'warsaw',
#  'newfoundland_and_labrador',
#  'botswana',
#  'senegal_and_gambia',
#  'magdeburg',
#  'groningen',
#  'bern',
#  'koblenz',
#  'district_of_columbia',
#  'north_america',
#  'wroclaw',
#  'dresden',
#  'gdansk',
#  'mainz',
#  'montpellier',
#  'alberta',
#  'norfolk',
#  'mexicocity',
#  'myanmar',
#  'usa',
#  'malopolskie',
#  'chubu',
#  'marseille',
#  'connecticut',
#  'ethiopia',
#  'rhode_island',
#  'iraq',
#  'mayotte',
#  'kassel',
#  'eritrea',
#  'nicaragua',
#  'rutland',
#  'tennessee',
#  'nord_est',
#  'nuernberg',
#  'baghdad',
#  'sanktpetersburg',
#  'koeln_regbez',
#  'limousin',
#  'equatorial_guinea',
#  'lapaz',
#  'portlandme',
#  'jerusalem',
#  'nunavut',
#  'warenmueritz',
#  'cuba',
#  'opolskie',
#  'bruegge',
#  'lakegarda',
#  'kanto',
#  'pakistan',
#  'montenegro',
#  'mecklenburg_vorpommern',
#  'staffordshire',
#  'congo_democratic_republic',
#  'haiti_and_domrep',
#  'ruegen',
#  'balaton',
#  'malmoe',
#  'freiburg_regbez',
#  'albania',
#  'miami',
#  'dallas',
#  'nova_scotia',
#  'pomorskie',
#  'corse',
#  'luxembourg',
#  'portoalegre',
#  'egypt',
#  'halle',
#  'oberbayern',
#  'katowice',
#  'bordeaux',
#  'south_america',
#  'norway',
#  'lima',
#  'johannesburg',
#  'west_virginia',
#  'maine',
#  'emden',
#  'centro',
#  'jamaica',
#  'wyoming',
#  'tucson',
#  'ulm',
#  'hamburg',
#  'washingtondc',
#  'namibia',
#  'ecuador',
#  'chugoku',
#  'albuquerque',
#  'oldenburg',
#  'rotterdam',
#  'alaska',
#  'trondheim',
#  'amsterdam',
#  'alexandria',
#  'orlando',
#  'france',
#  'copenhagen',
#  'russia',
#  'texas',
#  'estonia',
#  'cumbria',
#  'isle_of_man',
#  'jordan',
#  'hessen',
#  'zeeland',
#  'turin',
#  'languedoc_roussillon',
#  'scotland',
#  'poznan',
#  'cameroon',
#  'uzbekistan',
#  'curitiba',
#  'potsdam',
#  'sweden',
#  'czech_republic',
#  'warminsko_mazurskie',
#  'sofia',
#  'mexico',
#  'sarajewo',
#  'paraguay',
#  'guatemala',
#  'sydney',
#  'gloucestershire',
#  'finland',
#  'ivory_coast',
#  'iowa',
#  'arizona',
#  'wisconsin',
#  'konstanz',
#  'slaskie',
#  'quebec',
#  'bremerhaven',
#  'moldova',
#  'corsica',
#  'delaware',
#  'belize',
#  'reunion',
#  'centre',
#  'turkmenistan',
#  'suriname',
#  'lyon',
#  'cottbus',
#  'oslo',
#  'peru',
#  'benin',
#  'lithuania',
#  'manitoba',
#  'malaysia_singapore_brunei',
#  'jena',
#  'santiago',
#  'afghanistan',
#  'new_brunswick',
#  'bonn',
#  'schwaben',
#  'china',
#  'basse_normandie',
#  'chemnitz',
#  'wales',
#  'saigon',
#  'flensburg',
#  'merseyside',
#  'capetown',
#  'maldives',
#  'mississippi',
#  'zuerich',
#  'oxfordshire',
#  'liverpool',
#  'brazil',
#  'wien',
#  'new_york',
#  'pennsylvania',
#  'liechtenstein',
#  'karlsruhe',
#  'aquitaine',
#  'us_midwest',
#  'cairo',
#  'flevoland',
#  'malawi',
#  'swietokrzyskie',
#  'minnesota',
#  'british_columbia',
#  'burundi',
#  'riga',
#  'papua_new_guinea',
#  'canada',
#  'davis',
#  'brisbane',
#  'switzerland',
#  'newyorkcity',
#  'philippines',
#  'arnsberg_regbez',
#  'szczecin',
#  'cambridgeshire',
#  'rostock',
#  'missouri',
#  'isole',
#  'taiwan',
#  'tallinn',
#  'tyne_and_wear',
#  'libya',
#  'guinea_bissau',
#  'lausanne',
#  'luxemburg',
#  'marshall_islands',
#  'nauru',
#  'south_carolina',
#  'syria',
#  'colmar',
#  'brandenburg',
#  'lisbon',
#  'boulder',
#  'freiburg',
#  'tuvalu',
#  'venezuela',
#  'northamptonshire',
#  'sachsen_anhalt',
#  'friesland',
#  'dortmund',
#  'regensburg',
#  'rheinland_pfalz',
#  'sul',
#  'cheshire',
#  'surrey',
#  'centro_oeste',
#  'darmstadt',
#  'usedom',
#  'palma',
#  'fortcollins',
#  'manchester',
#  'kyushu',
#  'denver',
#  'luebeck',
#  'siberian_fed_district',
#  'west_yorkshire',
#  'samoa',
#  'new_caledonia',
#  'birmingham',
#  'serbia',
#  'bosnia_herzegovina',
#  'indonesia',
#  'haute_normandie',
#  'denhaag',
#  'sacramento',
#  'hannover',
#  'colombia',
#  'podkarpackie',
#  'central_america',
#  'kiribati',
#  'overijssel',
#  'leipzig',
#  'us_west',
#  'vanuatu',
#  'phnompenh',
#  'djibouti',
#  'beirut',
#  'gliwice',
#  'maastricht',
#  'bangladesh',
#  'zagreb',
#  'eindhoven',
#  'kaliningrad',
#  'gabon',
#  'bristol',
#  'frankfurt',
#  'tilburg',
#  'niedersachsen',
#  'indiana',
#  'durham',
#  'neworleans',
#  'bamberg',
#  'kujawsko_pomorskie',
#  'asia',
#  'rhone_alpes',
#  'nigeria',
#  'arkansas',
#  'mauritania',
#  'riodejaneiro',
#  'kansai',
#  'portland',
#  'bhutan',
#  'bombay',
#  'greater_manchester',
#  'kiew',
#  'greater_london',
#  'essex',
#  'lincolnshire',
#  'oklahoma',
#  'prag',
#  'comores',
#  'bedfordshire',
#  'washington',
#  'japan',
#  'kyrgyzstan',
#  'kosovo',
#  'slovenia',
#  'norte',
#  'ostrava',
#  'colorado',
#  'south_korea',
#  'oregon',
#  'bulgaria',
#  'romania',
#  'lubuskie',
#  'devon',
#  'uruguay',
#  'mozambique',
#  'podlaskie',
#  'genf',
#  'south_africa_and_lesotho',
#  'sierra_leone',
#  'baku',
#  'south_dakota',
#  'maryland',
#  'east_yorkshire_with_hull',
#  'saarland',
#  'memphis',
#  'sanfrancisco',
#  'england',
#  'graz',
#  'budapest',
#  'perth',
#  'muenster_regbez',
#  'victoria',
#  'us_northeast',
#  'zimbabwe',
#  'noord_holland',
#  'iran',
#  'kentucky',
#  'northumberland',
#  'tanzania',
#  'toronto',
#  'vermont',
#  'seychelles',
#  'worcestershire',
#  'niue',
#  'dorset',
#  'us_pacific',
#  'north_carolina',
#  'helsinki_region_pbf',
#  'osnabrueck',
#  'ontario',
#  'lodz',
#  'santabarbara',
#  'shikoku',
#  'dublin',
#  'pays_de_la_loire',
#  'wiltshire',
#  'wuerzburg',
#  'rwanda',
#  'west_sussex',
#  'ile_de_france',
#  'northwestern_fed_district',
#  'canary_islands',
#  'stuttgart',
#  'paloalto',
#  'northern_california',
#  'auckland',
#  'stockton',
#  'stuttgart_regbez',
#  'malta',
#  'massachusetts',
#  'linz',
#  'azerbaijan',
#  'duisburg',
#  'cracow',
#  'noord_brabant',
#  'sao_tome_and_principe',
#  'schleswig_holstein',
#  'india',
#  'swaziland',
#  'aarhus',
#  'tokyo',
#  'mazowieckie',
#  'provence_alpes_cote_d_azur',
#  'shropshire',
#  'montana',
#  'saarbruecken',
#  'aachen',
#  'florida',
#  'south_fed_district',
#  'lorraine',
#  'salzburg',
#  'oberfranken',
#  'champagne_ardenne',
#  'zuid_holland',
#  'north_korea',
#  'detmold_regbez',
#  'nebraska',
#  'lodzkie',
#  'dessau',
#  'karlsruhe_regbez',
#  'beijing',
#  'new_jersey',
#  'sanjose',
#  'poland',
#  'bangkok',
#  'nepal',
#  'kansas',
#  'bogota',
#  'antarctica',
#  'north_caucasus_fed_district',
#  'greece',
#  'niederbayern',
#  'berkeley',
#  'paderborn',
#  'kent',
#  'new_hampshire',
#  'croatia',
#  'chile',
#  'mannheim',
#  'spain',
#  'north_dakota',
#  'london',
#  'far_eastern_fed_district',
#  'laplata',
#  'togo',
#  'east_sussex',
#  'antwerpen',
#  'erfurt',
#  'africa',
#  'ohio',
#  'arnhem',
#  'melbourne',
#  'heilbronn',
#  'uganda',
#  'new_mexico',
#  'dolnoslaskie',
#  'lesotho',
#  'waterloo',
#  'helsinki',
#  'austin',
#  'glasgow',
#  'tunisia',
#  'oberpfalz',
#  'moscow',
#  'sheffield',
#  'goerlitz',
#  'corvallis',
#  'cambridge',
#  'frankfurtoder',
#  'sudan',
#  'argentina',
#  'thailand',
#  'clermontferrand',
#  'austria',
#  'drenthe',
#  'ulanbator',
#  'duesseldorf',
#  'nord_pas_de_calais',
#  'azores',
#  'bruessel',
#  'bahamas',
#  'muenchen',
#  'idaho',
#  'nevada',
#  'mongolia',
#  'sud',
#  'sri_lanka',
#  'warwickshire',
#  'south_yorkshire',
#  'chad',
#  'ukraine',
#  'ottawa',
#  'bochum',
#  'thueringen',
#  'unterfranken',
#  'lebanon',
#  'solomon_islands',
#  'portugal',
#  'wielkopolskie',
#  'hungary',
#  'brno',
#  'tuebingen_regbez',
#  'algeria',
#  'andorra',
#  'tohoku',
#  'porto',
#  'latvia',
#  'central_african_republic',
#  'israel_and_palestine',
#  'slovakia',
#  'belarus',
#  'faroe_islands',
#  'australia',
#  'tehran',
#  'nord_ovest',
#  'michigan',
#  'poitou_charentes',
#  'prince_edward_island',
#  'crimean_fed_district',
#  'hokkaido',
#  'hamm',
#  'mauritius',
#  'europe',
#  'franche_comte',
#  'berlin',
#  'oranienburg',
#  'somerset',
#  'yukon',
#  'moenchengladbach',
#  'kaunas',
#  'central_fed_district',
#  'craterlake',
#  'tonga',
#  'calgary',
#  'derbyshire',
#  'singapore',
#  'mali',
#  'berkshire',
#  'ireland_and_northern_ireland',
#  'isle_of_wight',
#  'belgium',
#  'midi_pyrenees',
#  'mittelfranken',
#  'armenia',
#  'laos',
#  'lancashire',
#  'kaiserslautern',
#  'leeds',
#  'iceland',
#  'sachsen',
#  'denmark',
#  'basel',
#  'auvergne',
#  'fiji',
#  'philadelphia',
#  'guadeloupe',
#  'illinois',
#  'angola',
#  'buenosaires',
#  'burkina_faso',
#  'bayern',
#  'saskatchewan',
#  'monaco',
#  'vietnam',
#  'madison',
#  'koeln',
#  'yemen',
#  'liberia',
#  'ghana',
#  'palau',
#  'strassburg',
#  'nottinghamshire',
#  'great_britain',
#  'istanbul',
#  'us_south',
#  'bolivia']
