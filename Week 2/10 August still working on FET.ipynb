# %%
import pandas as pd
import warnings
import re

# Suppress the specific UserWarning from openpyxl
warnings.filterwarnings("ignore", category=UserWarning, message="Data Validation extension is not supported")

# %%
# import pandas as pd

# Specify the path to the Excel file
excel_file_path = "FET ITP.xlsx"

# Specify the sheet name you want to read
sheet_name = "UG ITP 2021"

# Read the Excel file and the specified sheet into a DataFrame
df = pd.read_excel(excel_file_path, sheet_name=sheet_name, header=2)  # Note the 'header' parameter

# Now you have your data in the 'df' DataFrame
# print(df)
df.head()
# Out:
#    Unnamed: 0  No  \
# 0         NaN   1
# 1         NaN   2
# 2         NaN   3
# 3         NaN   4
# 4         NaN   5
#
#   Faculty(ies)/ Centres / Divisions - Involved in Collaboration  \
# 0                                                FET
# 1                                                FET
# 2                                                FET
# 3                                                FET
# 4                                                FET
#
#   Process owner / Champion / Project Leader  \
# 0                             Yong Yik Seng
# 1                             Yong Yik Seng
# 2                             Yong Yik Seng
# 3                             Yong Yik Seng
# 4                             Yong Yik Seng
#
#   Collaborator (ie Name of the Organization, Agency, Institution)  \
# 0                      2Y Communications Engineering
# 1                           AFA Technologies Sdn Bhd
# 2                     Alkhorayef Commercial Co. Ltd.
# ...

# %%
df_drop = df

# Selecting specific columns to create a new DataFrame
selected_columns = ['Collaborator (ie Name of the Organization, Agency, Institution)']
df_drop = df_drop[selected_columns]

# Rename the columns in the new DataFrame
new_column_names = ['Company']
df_drop.columns = new_column_names

# Display the new DataFrame
df_drop.head()
# Out:
#                           Company
# 0   2Y Communications Engineering
# 1        AFA Technologies Sdn Bhd
# 2  Alkhorayef Commercial Co. Ltd.
# 3             Alnajjah Enterprise
# 4    Alphabot Machinery Sdn. Bhd.

# %%
# specific_df_drop_2
# Save the updated DataFrame to a CSV file
output_csv_path = 'new_dataframe.csv'
df_drop.to_csv(output_csv_path, index=False)

print(f"New DataFrame saved to '{output_csv_path}'")
# Out:
# New DataFrame saved to 'new_dataframe.csv'

# %%
import pandas as pd

# Specify the path to the Excel file
excel_file_path = "new_dataframe__FET2022_cleaned.csv"

# # Specify the sheet name you want to read
# sheet_name = "UG ITP 2021"

# Read the Excel file and the specified sheet into a DataFrame
df = pd.read_csv(excel_file_path)

# Now you have your data in the 'df' DataFrame
# print(df)
df.head()
# Out:
#                               Company  \
# 0           6K Hyperspace (M) Sdn Bhd
# 1          Advenxus Solutions Sdn Bhd
# 2            AFA Technologies Sdn Bhd
# 3       Aiszzy Electronics Enterprise
# 4  Al Sadd Consulting Engineering Co.
#
#                                     Contact Person  \
# 0  Lim Meng Tin, Senior Mechanical Design Engineer
# 1                 Chong Sin Fatt, Service Engineer
# 2                  Lam Wen Haur, Assistant Manager
# 3               Nur \'aqilah Binti Zainuddin, Miss
# 4       Ahmed Altegani, Senior Mechanical Engineer
#
#                 Company Contact
# 0       mt.lim@interstella.tech
# 1         sf.chong@advenxus.com
# 2           lam.wh@afa-tech.com
# 3   aiszzyelectronics@gmail.com
# 4  a.altegani@alsaddconsult.com

# %%
# Create new columns in df_drop with empty values to match the columns in df
df_drop['Contact Person'] = ''
df_drop['Company Contact'] = ''

# Concatenate the DataFrames vertically
combined_df = pd.concat([df, df_drop], ignore_index=True)

# Now you have the combined DataFrame with df's columns and df_drop's 'Company' column filled with empty values
# print(combined_df)
# Out:
#                                                Company  \
# 0                            6K Hyperspace (M) Sdn Bhd
# 1                           Advenxus Solutions Sdn Bhd
# 2                             AFA Technologies Sdn Bhd
# 3                        Aiszzy Electronics Enterprise
# 4                   Al Sadd Consulting Engineering Co.
# ..                                                 ...
# 149  Wandel Engineering & Industrial Supplies Sdn. ...
# 150                         Wentel Engineering Sdn Bhd
# 151     Winco Precision Engineering (Melaka) Sdn. Bhd.
# 152  Yemen Egyptian Co. for Medical Industries and ...
# 153                 ZTE (Malaysia) Corporation Sdn Bhd
#
#                                       Contact Person  \
# 0    Lim Meng Tin, Senior Mechanical Design Engineer
# 1                   Chong Sin Fatt, Service Engineer
# 2                    Lam Wen Haur, Assistant Manager
# 3                 Nur \'aqilah Binti Zainuddin, Miss
# ...

# %%
combined_df.head()
# Out:
#                               Company  \
# 0           6K Hyperspace (M) Sdn Bhd
# 1          Advenxus Solutions Sdn Bhd
# 2            AFA Technologies Sdn Bhd
# 3       Aiszzy Electronics Enterprise
# 4  Al Sadd Consulting Engineering Co.
#
#                                     Contact Person  \
# 0  Lim Meng Tin, Senior Mechanical Design Engineer
# 1                 Chong Sin Fatt, Service Engineer
# 2                  Lam Wen Haur, Assistant Manager
# 3               Nur \'aqilah Binti Zainuddin, Miss
# 4       Ahmed Altegani, Senior Mechanical Engineer
#
#                 Company Contact
# 0       mt.lim@interstella.tech
# 1         sf.chong@advenxus.com
# 2           lam.wh@afa-tech.com
# 3   aiszzyelectronics@gmail.com
# 4  a.altegani@alsaddconsult.com

# %%
sorted_df = combined_df.sort_values(by='Company')

# print(sorted_df)
sorted_df.head()
# Out:
#                                  Company  \
# 58         2Y Communications Engineering
# 0              6K Hyperspace (M) Sdn Bhd
# 2               AFA Technologies Sdn Bhd
# 59              AFA Technologies Sdn Bhd
# 66  AWETEX ENGINEERING & TRADING SDN BHD
#
#                                      Contact Person          Company Contact
# 58
# 0   Lim Meng Tin, Senior Mechanical Design Engineer  mt.lim@interstella.tech
# 2                   Lam Wen Haur, Assistant Manager      lam.wh@afa-tech.com
# 59
# 66

# %%
# import pandas as pd

# Assuming you have already created the combined_df DataFrame as shown in the previous response

# Drop duplicates while keeping rows with values in 'Contact Person' and 'Company Contact'
combined_df_cleaned = combined_df.drop_duplicates(subset=['Company'], keep='first')

# Now you have the cleaned DataFrame with duplicates removed, retaining rows with values in 'Contact Person' and 'Company Contact'
# print(combined_df_cleaned)
combined_df_cleaned.head()
# Out:
#                               Company  \
# 0           6K Hyperspace (M) Sdn Bhd
# 1          Advenxus Solutions Sdn Bhd
# 2            AFA Technologies Sdn Bhd
# 3       Aiszzy Electronics Enterprise
# 4  Al Sadd Consulting Engineering Co.
#
#                                     Contact Person  \
# 0  Lim Meng Tin, Senior Mechanical Design Engineer
# 1                 Chong Sin Fatt, Service Engineer
# 2                  Lam Wen Haur, Assistant Manager
# 3               Nur \'aqilah Binti Zainuddin, Miss
# 4       Ahmed Altegani, Senior Mechanical Engineer
#
#                 Company Contact
# 0       mt.lim@interstella.tech
# 1         sf.chong@advenxus.com
# 2           lam.wh@afa-tech.com
# 3   aiszzyelectronics@gmail.com
# 4  a.altegani@alsaddconsult.com

# %%
combined_df_cleaned_2 = combined_df_cleaned.sort_values(by='Company')

# print(sorted_df)
combined_df_cleaned_2.tail()
# Out:
#                                                Company  \
# 55                          Wentel Engineering Sdn Bhd
# 56      Winco Precision Engineering (Melaka) Sdn. Bhd.
# 152  Yemen Egyptian Co. for Medical Industries and ...
# 153                 ZTE (Malaysia) Corporation Sdn Bhd
# 25                                      iRadar Sdn Bhd
#
#                             Contact Person              Company Contact
# 55     Chai Siew Fong, Engineering Manager  chai.siewfong@wenteleng.com
# 56   Stalin Chelladhas, Technical Director           csttalin@gmail.com
# 152
# 153
# 25      Miss Choo Ai Ling, Project Manager         alchoo@iradar.com.my

# %%
# specific_df_drop_2
# Save the updated DataFrame to a CSV file
output_csv_path = 'new_dataframe.csv'
combined_df_cleaned_2.to_csv(output_csv_path, index=False)

print(f"New DataFrame saved to '{output_csv_path}'")
# Out:
# New DataFrame saved to 'new_dataframe.csv'

# %%
# Find the row index where 'Company' column matches the specified company name
index_to_remove = combined_df_cleaned_2[combined_df_cleaned_2['Company'] == 'Intel Microrelectronics (M) Sdn Bhd'].index

# Remove the row with the found index
combined_df_cleaned_2 = combined_df_cleaned_2.drop(index_to_remove)

# Now you have the DataFrame with the row removed
# print(combined_df_cleaned_2)
combined_df_cleaned_2.head()
# Out:
#                                  Company  \
# 58         2Y Communications Engineering
# 0              6K Hyperspace (M) Sdn Bhd
# 2               AFA Technologies Sdn Bhd
# 66  AWETEX ENGINEERING & TRADING SDN BHD
# 1             Advenxus Solutions Sdn Bhd
#
#                                      Contact Person          Company Contact
# 58
# 0   Lim Meng Tin, Senior Mechanical Design Engineer  mt.lim@interstella.tech
# 2                   Lam Wen Haur, Assistant Manager      lam.wh@afa-tech.com
# 66
# 1                  Chong Sin Fatt, Service Engineer    sf.chong@advenxus.com

# %%
# specific_df_drop_2
# Save the updated DataFrame to a CSV file
output_csv_path = 'new_dataframe_10_8_final_FET.csv'
combined_df_cleaned_2.to_csv(output_csv_path, index=False)

print(f"New DataFrame saved to '{output_csv_path}'")
# Out:
# New DataFrame saved to 'new_dataframe_10_8_final_FET.csv'

# %%
#the dataframe for FCA
# import pandas as pd
df = pd.read_csv("new_dataframe_FCA_final.csv")
# print(df)
df.head()
# Out:
#                   Company                                     Contact Person  \
# 0      Dialektika Sdn Bhd   Sayed Munawar, Ketua Pegawai Eksekutif\nMohd ...
# 1  ZY Digital Productions     Cheng Zhang YI, Founder, ZY Digital Production
# 2    Youth AK Productions  Kartik Kumar a/l Vijayakumar, Chief Managing O...
# 3              WE ARE KIX                           Ion Furjanic, WE ARE KIX
# 4           Valar Studios             Lim Hui Hsing, Director, Valar Studios
#
#                        Company Contact           Company Email   Company Tel
# 0  admin@dialektika.com\n 012-4144664,    admin@dialektika.com   012-4144664
# 1   ZY@zyproductions.com\n014-63747000    ZY@zyproductions.com  014-63747000
# 2   kartik.ypak@gmail.com\n016-2438220   kartik.ypak@gmail.com   016-2438220
# 3                     ion@wearekix.com        ion@wearekix.com           NaN
# 4  hsing@valarstudios.com\n016-7780926  hsing@valarstudios.com   016-7780926

# %%
# Split the 'Contact Person' column by the first comma and expand it into new columns
split_data = df['Contact Person'].str.split(',', n=1, expand=True)

# Assign the first split as 'Contact Person' and the second split as 'Position'
df['Contact Person'] = split_data[0]
df['Position'] = split_data[1]

# Now you have the DataFrame with the 'Contact Person' column split into 'Contact Person' and 'Position' columns
# print(df)
df.head()
# Out:
#                   Company                Contact Person  \
# 0      Dialektika Sdn Bhd                 Sayed Munawar
# 1  ZY Digital Productions                Cheng Zhang YI
# 2    Youth AK Productions  Kartik Kumar a/l Vijayakumar
# 3              WE ARE KIX                  Ion Furjanic
# 4           Valar Studios                 Lim Hui Hsing
#
#                        Company Contact           Company Email   Company Tel  \
# 0  admin@dialektika.com\n 012-4144664,    admin@dialektika.com   012-4144664
# 1   ZY@zyproductions.com\n014-63747000    ZY@zyproductions.com  014-63747000
# 2   kartik.ypak@gmail.com\n016-2438220   kartik.ypak@gmail.com   016-2438220
# 3                     ion@wearekix.com        ion@wearekix.com           NaN
# 4  hsing@valarstudios.com\n016-7780926  hsing@valarstudios.com   016-7780926
#
#                                             Position
# 0   Ketua Pegawai Eksekutif\nMohd Suhaili Umar, J...
# 1                     Founder, ZY Digital Production
# ...

# %%
df# specific_df_drop_2
# Save the updated DataFrame to a CSV file
output_csv_path = 'new_dataframe.csv'
df.to_csv(output_csv_path, index=False)

print(f"New DataFrame saved to '{output_csv_path}'")
# Out:
# New DataFrame saved to 'new_dataframe.csv'

# %%
df_new = df
# Remove content after the comma in the 'Position' column
df_new['Position'] = df_new['Position'].str.replace(r',.*$', '', regex=True)

# Now you have the DataFrame with the content after the comma removed from the 'Position' column
# print(df)
df_new.head()
# Out:
#                   Company                Contact Person  \
# 0      Dialektika Sdn Bhd                 Sayed Munawar
# 1  ZY Digital Productions                Cheng Zhang YI
# 2    Youth AK Productions  Kartik Kumar a/l Vijayakumar
# 3              WE ARE KIX                  Ion Furjanic
# 4           Valar Studios                 Lim Hui Hsing
#
#                        Company Contact           Company Email   Company Tel  \
# 0  admin@dialektika.com\n 012-4144664,    admin@dialektika.com   012-4144664
# 1   ZY@zyproductions.com\n014-63747000    ZY@zyproductions.com  014-63747000
# 2   kartik.ypak@gmail.com\n016-2438220   kartik.ypak@gmail.com   016-2438220
# 3                     ion@wearekix.com        ion@wearekix.com           NaN
# 4  hsing@valarstudios.com\n016-7780926  hsing@valarstudios.com   016-7780926
#
#                                       Position
# 0   Ketua Pegawai Eksekutif\nMohd Suhaili Umar
# 1                                      Founder
# ...

# %%
df# specific_df_drop_2
# Save the updated DataFrame to a CSV file
output_csv_path = 'new_dataframe.csv'
df_new.to_csv(output_csv_path, index=False)

print(f"New DataFrame saved to '{output_csv_path}'")
# Out:
# New DataFrame saved to 'new_dataframe.csv'

# %%
# # df_new = pd.DataFrame(data)
# df_new_test = df_new

# # Extract phone numbers using regular expressions
# phone_numbers = df_new_test['Company Contact'].str.extract(r'([+\d-]+)')

# # Create a new column 'Com Tel2' with extracted phone numbers
# df_new_test['Com Tel2'] = phone_numbers

# # Remove email addresses from 'Company Contact' column
# # df_new_test['Company Contact'] = df_new_test['Company Contact'].str.replace(r'\S+@\S+', '', regex=True)

# # Display the modified DataFrame
# # print(df_new_test)
# df_new_test.head()

# %%
# df# specific_df_drop_2
# # Save the updated DataFrame to a CSV file
# output_csv_path = 'new_dataframe.csv'
# df_new_test.to_csv(output_csv_path, index=False)

# print(f"New DataFrame saved to '{output_csv_path}'")

# %%
# df = pd.DataFrame(data)
df = df_new


# Extract phone numbers using the provided regex pattern
phone_pattern = r'(?:(?:\+\d{1,2}[-.\s]?)?(?:\d{3,5}[-.\s]?\d{6,8}|\(\d{3,5}\)[-\s]?\d{6,8}))'
phone_numbers = df['Company Contact'].str.extract(rf'.*?\n\s*({phone_pattern})')

# Add apostrophes around phone numbers
formatted_phone_numbers = phone_numbers.applymap(lambda x: f"'{x}'" if pd.notna(x) else '')

# Add apostrophes around phone numbers
formatted_phone_numbers = phone_numbers.applymap(lambda x: f"'{x}'" if pd.notna(x) else '')

# Create a new column 'Tel 2' with formatted phone numbers
df['Tel 2'] = formatted_phone_numbers[0]

# Display the modified DataFrame
print(df)
# Out:
#                                         Company                Contact Person  \
# 0                            Dialektika Sdn Bhd                 Sayed Munawar
# 1                        ZY Digital Productions                Cheng Zhang YI
# 2                          Youth AK Productions  Kartik Kumar a/l Vijayakumar
# 3                                    WE ARE KIX                  Ion Furjanic
# 4                                 Valar Studios                 Lim Hui Hsing
# 5           The Star Media Group Berhad (R.AGE)                       Ian Yee
# 6                           Tech Action Sdn Bhd                   Pauline Kim
# 7                             SWF Films Sdn Bhd                    Diana Tang
# 8                        Studio Kembara Sdn Bhd      Mohamad Afiq B Md Razali
# 9            Studio Five Corp - The Media Group                        Fareez
# 10                         Shoryuken Production            Wongsakorn Jaihuab
# ...

# %%
# df# specific_df_drop_2
# Save the updated DataFrame to a CSV file
output_csv_path = 'new_dataframe.csv'
df.to_csv(output_csv_path, index=False)

print(f"New DataFrame saved to '{output_csv_path}'")
# Out:
# New DataFrame saved to 'new_dataframe.csv'

# %%
df = pd.read_csv("new_dataframe.csv")
# print(df)
df.head()
# Out:
#                   Company                Contact Person  \
# 0      Dialektika Sdn Bhd                 Sayed Munawar
# 1  ZY Digital Productions                Cheng Zhang YI
# 2    Youth AK Productions  Kartik Kumar a/l Vijayakumar
# 3              WE ARE KIX                  Ion Furjanic
# 4           Valar Studios                 Lim Hui Hsing
#
#                        Company Contact           Company Email   Company Tel  \
# 0  admin@dialektika.com\n 012-4144664,    admin@dialektika.com   012-4144664
# 1   ZY@zyproductions.com\n014-63747000    ZY@zyproductions.com  014-63747000
# 2   kartik.ypak@gmail.com\n016-2438220   kartik.ypak@gmail.com   016-2438220
# 3                     ion@wearekix.com        ion@wearekix.com           NaN
# 4  hsing@valarstudios.com\n016-7780926  hsing@valarstudios.com   016-7780926
#
#                                       Position           Tel 2
# 0   Ketua Pegawai Eksekutif\nMohd Suhaili Umar   '012-4144664'
# ...

# %%
# Delete specific columns
columns_to_delete = ['Company Contact', 'Company Tel']
df = df.drop(columns=columns_to_delete, axis=1)

# Display the modified DataFrame
# print(df)
df.head()
# Out:
#                   Company                Contact Person  \
# 0      Dialektika Sdn Bhd                 Sayed Munawar
# 1  ZY Digital Productions                Cheng Zhang YI
# 2    Youth AK Productions  Kartik Kumar a/l Vijayakumar
# 3              WE ARE KIX                  Ion Furjanic
# 4           Valar Studios                 Lim Hui Hsing
#
#             Company Email                                     Position  \
# 0    admin@dialektika.com   Ketua Pegawai Eksekutif\nMohd Suhaili Umar
# 1    ZY@zyproductions.com                                      Founder
# 2   kartik.ypak@gmail.com                       Chief Managing Officer
# 3        ion@wearekix.com                                   WE ARE KIX
# 4  hsing@valarstudios.com                                     Director
#
#             Tel 2
# 0   '012-4144664'
# 1  '014-63747000'
# 2   '016-2438220'
# 3             NaN
# 4   '016-7780926'

# %%
# Rearrange the columns in the desired order
column_order = ['Company', 'Tel 2', 'Company Email', 'Contact Person', 'Position']
df = df[column_order]

# Display the modified DataFrame
# print(df)
df.head()
# Out:
#                   Company           Tel 2           Company Email  \
# 0      Dialektika Sdn Bhd   '012-4144664'    admin@dialektika.com
# 1  ZY Digital Productions  '014-63747000'    ZY@zyproductions.com
# 2    Youth AK Productions   '016-2438220'   kartik.ypak@gmail.com
# 3              WE ARE KIX             NaN        ion@wearekix.com
# 4           Valar Studios   '016-7780926'  hsing@valarstudios.com
#
#                  Contact Person                                     Position
# 0                 Sayed Munawar   Ketua Pegawai Eksekutif\nMohd Suhaili Umar
# 1                Cheng Zhang YI                                      Founder
# 2  Kartik Kumar a/l Vijayakumar                       Chief Managing Officer
# 3                  Ion Furjanic                                   WE ARE KIX
# 4                 Lim Hui Hsing                                     Director

# %%
# Change the name of a specific column
new_column_name = 'Company Tel'
df = df.rename(columns={'Tel 2': new_column_name})

# Display the modified DataFrame
# 
df.head()
# Out:
#                   Company     Company Tel           Company Email  \
# 0      Dialektika Sdn Bhd   '012-4144664'    admin@dialektika.com
# 1  ZY Digital Productions  '014-63747000'    ZY@zyproductions.com
# 2    Youth AK Productions   '016-2438220'   kartik.ypak@gmail.com
# 3              WE ARE KIX             NaN        ion@wearekix.com
# 4           Valar Studios   '016-7780926'  hsing@valarstudios.com
#
#                  Contact Person                                     Position
# 0                 Sayed Munawar   Ketua Pegawai Eksekutif\nMohd Suhaili Umar
# 1                Cheng Zhang YI                                      Founder
# 2  Kartik Kumar a/l Vijayakumar                       Chief Managing Officer
# 3                  Ion Furjanic                                   WE ARE KIX
# 4                 Lim Hui Hsing                                     Director

# %%
new_df = df
# Add an empty 'Address' column between 'Company' and 'Company Tel'
new_column_name = 'Address'
new_df.insert(loc=new_df.columns.get_loc('Company Tel'), column=new_column_name, value='')

# Display the modified DataFrame
# print(new_df)
new_df.head()
# Out:
#                   Company Address     Company Tel           Company Email  \
# 0      Dialektika Sdn Bhd           '012-4144664'    admin@dialektika.com
# 1  ZY Digital Productions          '014-63747000'    ZY@zyproductions.com
# 2    Youth AK Productions           '016-2438220'   kartik.ypak@gmail.com
# 3              WE ARE KIX                     NaN        ion@wearekix.com
# 4           Valar Studios           '016-7780926'  hsing@valarstudios.com
#
#                  Contact Person                                     Position
# 0                 Sayed Munawar   Ketua Pegawai Eksekutif\nMohd Suhaili Umar
# 1                Cheng Zhang YI                                      Founder
# 2  Kartik Kumar a/l Vijayakumar                       Chief Managing Officer
# 3                  Ion Furjanic                                   WE ARE KIX
# 4                 Lim Hui Hsing                                     Director

# %%
new_df = new_df.sort_values(by='Company')

# print(sorted_df)
new_df.head()
# Out:
#                         Company Address    Company Tel  \
# 50  Al Hijrah Media Corporation          '017-8780942'
# 49       Another Planet Sdn Bhd          '014-3488123'
# 48              Apparat Sdn Bhd          '019-2347317'
# 47  Arara Entertainment Sdn Bhd          '012-2653253'
# 46          Arts World Pictures           '6380438487'
#
#                Company Email           Contact Person                Position
# 50     izuddin@tvahijrah.com  Mohd Izuddin Bin Yaakub   Ketua Jabatan Kreatif
# 49        mo@planetfilms.com           Muhammad Bahir                Producer
# 48         nansolo@gmail.com          Nandita Solomon          CEO & Producer
# 47        fungrytv@gmail.com             Razif Hashim        Company Director
# 46  ramaprakashr82@gmail.com           R.Rama Prakash             Co-Director

# %%
new_new_df = new_df
# Add empty columns 'FCA' and 'FET' after 'Position' column
new_columns_data = {'FCA': '1', 'FET': '0'}
for column, default_value in new_columns_data.items():
    new_new_df.insert(loc=new_new_df.columns.get_loc('Position') + 1, column=column, value=default_value)

# Display the modified DataFrame
# print(df)
new_new_df.head()
# Out:
#                         Company Address    Company Tel  \
# 50  Al Hijrah Media Corporation          '017-8780942'
# 49       Another Planet Sdn Bhd          '014-3488123'
# 48              Apparat Sdn Bhd          '019-2347317'
# 47  Arara Entertainment Sdn Bhd          '012-2653253'
# 46          Arts World Pictures           '6380438487'
#
#                Company Email           Contact Person                Position  \
# 50     izuddin@tvahijrah.com  Mohd Izuddin Bin Yaakub   Ketua Jabatan Kreatif
# 49        mo@planetfilms.com           Muhammad Bahir                Producer
# 48         nansolo@gmail.com          Nandita Solomon          CEO & Producer
# 47        fungrytv@gmail.com             Razif Hashim        Company Director
# 46  ramaprakashr82@gmail.com           R.Rama Prakash             Co-Director
#
#    FET FCA
# 50   0   1
# 49   0   1
# 48   0   1
# 47   0   1
# 46   0   1

# %%
output_csv_path = 'new_dataframe_10_8_final_FCA.csv'
new_new_df.to_csv(output_csv_path, index=False)

print(f"New DataFrame saved to '{output_csv_path}'")
# Out:
# New DataFrame saved to 'new_dataframe_10_8_final_FCA.csv'

# %%
# #to fix the FET data before combining
# df = pd.read_csv("new_dataframe_10_8_final_FET.csv")
# # print(df)
# # df.head()

# %%
# import pandas as pd

# Read the CSV file
df = pd.read_csv("new_dataframe_10_8_final_FET.csv")

# Split the 'Contact Person' column by the first comma and expand it into new columns
split_data = df['Contact Person'].str.split(',', n=1, expand=True)

# Assign the first split as 'Contact Person' and the second split as 'Position'
df['Contact Person'] = split_data[0]
df['Position'] = split_data[1]

# Keep 'Jabil Circuit Sdn Bhd' row's 'Contact Person' and 'Position' columns intact
jabil_row = df['Company'] == 'Jabil Circuit Sdn Bhd'
df.loc[jabil_row, ['Contact Person', 'Position']] = df.loc[jabil_row, ['Contact Person', 'Position']].fillna('')

# Now you have the DataFrame with the 'Contact Person' column split into 'Contact Person' and 'Position' columns,
# and the 'Jabil Circuit Sdn Bhd' row's columns preserved
print(df.head())
# Out:
#                                 Company  Contact Person  \
# 0         2Y Communications Engineering             NaN
# 1             6K Hyperspace (M) Sdn Bhd    Lim Meng Tin
# 2              AFA Technologies Sdn Bhd    Lam Wen Haur
# 3  AWETEX ENGINEERING & TRADING SDN BHD             NaN
# 4            Advenxus Solutions Sdn Bhd  Chong Sin Fatt
#
#            Company Contact                            Position
# 0                      NaN                                 NaN
# 1  mt.lim@interstella.tech   Senior Mechanical Design Engineer
# 2      lam.wh@afa-tech.com                   Assistant Manager
# 3                      NaN                                 NaN
# 4    sf.chong@advenxus.com                    Service Engineer

# %%
# specific_df_drop_2
# Save the updated DataFrame to a CSV file
output_csv_path = 'new_dataframe.csv'
df.to_csv(output_csv_path, index=False)

print(f"New DataFrame saved to '{output_csv_path}'")
# Out:
# New DataFrame saved to 'new_dataframe.csv'

# %%
# Sample data for demonstration
data = {'Company': ['Jabil Circuit Sdn Bhd'],
        'Contact Person': ['Premdass Devaray;Choyai Wong'],
        'Company Contact': ['Premdass_DevaRay@jabil.com; choyai_wong@jabil.com'],
        'Position': ['Sr. Supplier Quality Engineer;Global Materials Quote Manager Supply Chain Management']}

new_data_df = pd.DataFrame(data)

# Read the existing CSV file
existing_df = pd.read_csv("new_dataframe_10_8_final_FET.csv")

# Combine the existing DataFrame and the new data DataFrame
combined_df = pd.concat([existing_df, new_data_df], ignore_index=True)

# Display the combined DataFrame
print(combined_df)

# %%
# import pandas as pd

# Read the CSV file
df = pd.read_csv("new_dataframe_10_8_final_FET.csv")

# Define a list of companies to preserve
companies_to_preserve = ['Company A', 'Company B', 'Company C', 'Jabil Circuit Sdn Bhd']  # Add more companies as needed

# Filter out rows with companies to preserve
filtered_df = df[df['Company'].isin(companies_to_preserve)]

# Split the 'Contact Person' column by the first comma and expand it into new columns
split_data = filtered_df['Contact Person'].str.split(',', n=1, expand=True)

# Assign the first split as 'Contact Person' and the second split as 'Position'
filtered_df['Contact Person'] = split_data[0]
filtered_df['Position'] = split_data[1]

# Now you have the DataFrame with the 'Contact Person' column split into 'Contact Person' and 'Position' columns,
# and the selected companies' rows' columns preserved
print(filtered_df.head())
# Out:
#                   Company    Contact Person  \
# 54  Jabil Circuit Sdn Bhd  Premdass Devaray
#
#                                       Company Contact  \
# 54  Premdass_DevaRay@jabil.com; choyai_wong@jabil.com
#
#                                              Position
# 54   Sr. Supplier Quality Engineer; Choyai Wong, G...
# C:\Users\AIMAN\AppData\Local\Temp\ipykernel_6692\3886396624.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['Contact Person'] = split_data[0]
# C:\Users\AIMAN\AppData\Local\Temp\ipykernel_6692\3886396624.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
# specific_df_drop_2
# Save the updated DataFrame to a CSV file
output_csv_path = 'new_dataframe.csv'
filtered_df.to_csv(output_csv_path, index=False)

print(f"New DataFrame saved to '{output_csv_path}'")
# Out:
# New DataFrame saved to 'new_dataframe.csv'

# %%
#new this one makes the new FET final

Company,Contact Person,Company Contact
Inter Syspro Sdn. Bhd.,"Chin Yoon Seng, Supervisor",admin@intersyspro.net
Jabil Circuit Sdn Bhd,"Premdass Devaray, Sr. Supplier Quality Engineer; Choyai Wong, Global Materials Quote Manager Supply Chain Management",Premdass_DevaRay@jabil.com; choyai_wong@jabil.com
K. K. Metal Processing Sdn. Bhd.,,


'Company': ['Inter Syspro Sdn. Bhd.', 'Jabil Circuit Sdn Bhd', 'K. K. Metal Processing Sdn. Bhd.']
'Contact Person': ['Chin Yoon Seng, Supervisor','Premdass Devaray, Sr. Supplier Quality Engineer; Choyai Wong, Global Materials Quote Manager Supply Chain Management','']
'Company Contact': ['admin@intersyspro.net','Premdass_DevaRay@jabil.com; choyai_wong@jabil.com','']



'Company': ['Inter Syspro Sdn. Bhd.', 'Jabil Circuit Sdn Bhd', 'K. K. Metal Processing Sdn. Bhd.']
'Contact Person': ['Chin Yoon Seng','Premdass Devaray;Choyai Wong','']
'Company Email': ['admin@intersyspro.net','Premdass_DevaRay@jabil.com; choyai_wong@jabil.com','']
'Position': ['Supervisor','Sr. Supplier Quality Engineer;Global Materials Quote Manager Supply Chain Management','']
    
    
Premdass Devaray, Sr. Supplier Quality Engineer; Choyai Wong, Global Materials Quote Manager Supply Chain Management

Premdass Devaray;Choyai Wong
Sr. Supplier Quality Engineer;Global Materials Quote Manager Supply Chain Management

# %%
import pandas as pd

# Sample data for demonstration
data = {'Company': ['Inter Syspro Sdn. Bhd.', 'Jabil Circuit Sdn Bhd', 'K. K. Metal Processing Sdn. Bhd.'],
        'Contact Person': ['Chin Yoon Seng, Supervisor',
                            'Premdass Devaray, Sr. Supplier Quality Engineer; Choyai Wong, Global Materials Quote Manager Supply Chain Management',
                            ''],
        'Company Contact': ['admin@intersyspro.net',
                            'Premdass_DevaRay@jabil.com; choyai_wong@jabil.com',
                            '']}

df = pd.DataFrame(data)

# Split 'Contact Person' by the first comma and the semicolon
split_data = df['Contact Person'].str.split(', ', n=1, expand=True)
semicolon_split = split_data[1].str.split('; ', n=1, expand=True)

# Assign the first split as 'Contact Person' and the second split as 'Position'
df['Contact Person'] = semicolon_split[0].fillna(split_data[1])
df['Position'] = semicolon_split[1].fillna('')

# Add 'Company Email' column by splitting 'Company Contact'
df['Company Email'] = df['Company Contact'].str.split(';').str[0]

# Display the modified DataFrame
print(df)
# Out:
#                             Company                 Contact Person  \
# 0            Inter Syspro Sdn. Bhd.                     Supervisor
# 1             Jabil Circuit Sdn Bhd  Sr. Supplier Quality Engineer
# 2  K. K. Metal Processing Sdn. Bhd.                           None
#
#                                      Company Contact  \
# 0                              admin@intersyspro.net
# 1  Premdass_DevaRay@jabil.com; choyai_wong@jabil.com
# 2
#
#                                             Position  \
# 0
# 1  Choyai Wong, Global Materials Quote Manager Su...
# 2
#
#                 Company Email
# 0       admin@intersyspro.net
# 1  Premdass_DevaRay@jabil.com
# 2

# %%
# specific_df_drop_2
# Save the updated DataFrame to a CSV file
output_csv_path = 'new_dataframe.csv'
df.to_csv(output_csv_path, index=False)

print(f"New DataFrame saved to '{output_csv_path}'")
# Out:
# New DataFrame saved to 'new_dataframe.csv'

# %% [markdown]
# New method, hopefully less retarded

# %%
#new_dataframe_10_8_final_FET - Copy.csv

# import pandas as pd

# Read the CSV file
df = pd.read_csv("new_dataframe_10_8_final_FET - Copy.csv")

# Split the 'Contact Person' column by the first comma and expand it into new columns
split_data = df['Contact Person'].str.split(',', n=1, expand=True)

# Assign the first split as 'Contact Person' and the second split as 'Position'
df['Contact Person'] = split_data[0]
df['Position'] = split_data[1]

# # Keep 'Jabil Circuit Sdn Bhd' row's 'Contact Person' and 'Position' columns intact
# jabil_row = df['Company'] == 'Jabil Circuit Sdn Bhd'
# df.loc[jabil_row, ['Contact Person', 'Position']] = df.loc[jabil_row, ['Contact Person', 'Position']].fillna('')

# Now you have the DataFrame with the 'Contact Person' column split into 'Contact Person' and 'Position' columns,
# and the 'Jabil Circuit Sdn Bhd' row's columns preserved
# print(df.head())

# specific_df_drop_2
# Save the updated DataFrame to a CSV file
output_csv_path = 'new_dataframe.csv'
df.to_csv(output_csv_path, index=False)

print(f"New DataFrame saved to '{output_csv_path}'")
# Out:
# New DataFrame saved to 'new_dataframe.csv'

# %%
df.head()
# Out:
#                                 Company  Contact Person  \
# 0         2Y Communications Engineering             NaN
# 1             6K Hyperspace (M) Sdn Bhd    Lim Meng Tin
# 2              AFA Technologies Sdn Bhd    Lam Wen Haur
# 3  AWETEX ENGINEERING & TRADING SDN BHD             NaN
# 4            Advenxus Solutions Sdn Bhd  Chong Sin Fatt
#
#            Company Contact                            Position
# 0                      NaN                                 NaN
# 1  mt.lim@interstella.tech   Senior Mechanical Design Engineer
# 2      lam.wh@afa-tech.com                   Assistant Manager
# 3                      NaN                                 NaN
# 4    sf.chong@advenxus.com                    Service Engineer

# %%
# Rearrange the columns in the desired order
column_order = ['Company', 'Company Contact', 'Contact Person', 'Position']
df = df[column_order]

# Display the modified DataFrame
# print(df)
df.head()
# Out:
#                                 Company          Company Contact  \
# 0         2Y Communications Engineering                      NaN
# 1             6K Hyperspace (M) Sdn Bhd  mt.lim@interstella.tech
# 2              AFA Technologies Sdn Bhd      lam.wh@afa-tech.com
# 3  AWETEX ENGINEERING & TRADING SDN BHD                      NaN
# 4            Advenxus Solutions Sdn Bhd    sf.chong@advenxus.com
#
#    Contact Person                            Position
# 0             NaN                                 NaN
# 1    Lim Meng Tin   Senior Mechanical Design Engineer
# 2    Lam Wen Haur                   Assistant Manager
# 3             NaN                                 NaN
# 4  Chong Sin Fatt                    Service Engineer

# %%
# Change the name of a specific column
new_column_name = 'Company Email'
df = df.rename(columns={'Company Contact': new_column_name})

df.head()
# Out:
#                                 Company            Company Email  \
# 0         2Y Communications Engineering                      NaN
# 1             6K Hyperspace (M) Sdn Bhd  mt.lim@interstella.tech
# 2              AFA Technologies Sdn Bhd      lam.wh@afa-tech.com
# 3  AWETEX ENGINEERING & TRADING SDN BHD                      NaN
# 4            Advenxus Solutions Sdn Bhd    sf.chong@advenxus.com
#
#    Contact Person                            Position
# 0             NaN                                 NaN
# 1    Lim Meng Tin   Senior Mechanical Design Engineer
# 2    Lam Wen Haur                   Assistant Manager
# 3             NaN                                 NaN
# 4  Chong Sin Fatt                    Service Engineer

# %%
new_df = df
# Add an empty 'Address' column between 'Company' and 'Company Tel'
new_column_name = 'Address'
new_df.insert(loc=new_df.columns.get_loc('Company Email'), column=new_column_name, value='')

new_column_name = 'Company Tel'
new_df.insert(loc=new_df.columns.get_loc('Company Email'), column=new_column_name, value='')


# Display the modified DataFrame
# print(new_df)
new_df.head()
# Out:
#                                 Company Address Company Tel  \
# 0         2Y Communications Engineering
# 1             6K Hyperspace (M) Sdn Bhd
# 2              AFA Technologies Sdn Bhd
# 3  AWETEX ENGINEERING & TRADING SDN BHD
# 4            Advenxus Solutions Sdn Bhd
#
#              Company Email  Contact Person                            Position
# 0                      NaN             NaN                                 NaN
# 1  mt.lim@interstella.tech    Lim Meng Tin   Senior Mechanical Design Engineer
# 2      lam.wh@afa-tech.com    Lam Wen Haur                   Assistant Manager
# 3                      NaN             NaN                                 NaN
# 4    sf.chong@advenxus.com  Chong Sin Fatt                    Service Engineer

# %%
new_new_df = new_df
# Add empty columns 'FCA' and 'FET' after 'Position' column
new_columns_data = {'FCA': '0', 'FET': '1'}
for column, default_value in new_columns_data.items():
    new_new_df.insert(loc=new_new_df.columns.get_loc('Position') + 1, column=column, value=default_value)

# Display the modified DataFrame
# print(df)
new_new_df.head()
# Out:
#                                 Company Address Company Tel  \
# 0         2Y Communications Engineering
# 1             6K Hyperspace (M) Sdn Bhd
# 2              AFA Technologies Sdn Bhd
# 3  AWETEX ENGINEERING & TRADING SDN BHD
# 4            Advenxus Solutions Sdn Bhd
#
#              Company Email  Contact Person  \
# 0                      NaN             NaN
# 1  mt.lim@interstella.tech    Lim Meng Tin
# 2      lam.wh@afa-tech.com    Lam Wen Haur
# 3                      NaN             NaN
# 4    sf.chong@advenxus.com  Chong Sin Fatt
#
#                              Position FET FCA
# 0                                 NaN   1   0
# 1   Senior Mechanical Design Engineer   1   0
# 2                   Assistant Manager   1   0
# 3                                 NaN   1   0
# 4                    Service Engineer   1   0

# %%
# specific_df_drop_2
# Save the updated DataFrame to a CSV file
output_csv_path = 'new_dataframe_10_8_final_FET_for_reals_this_time.csv'
new_new_df.to_csv(output_csv_path, index=False)

print(f"New DataFrame saved to '{output_csv_path}'")
# Out:
# New DataFrame saved to 'new_dataframe_10_8_final_FET_for_reals_this_time.csv'

# %%
df = pd.read_csv("new_dataframe_10_8_final_FET_for_reals_this_time.csv")
df_2 = pd.read_csv("new_dataframe_10_8_final_FCA.csv")

# Append the dataframes together
combined_df = pd.concat([df, df_2], ignore_index=True)

new_df = combined_df.sort_values(by='Company')

# print(sorted_df)
new_df.head()
# Out:
#                                 Company  Address Company Tel  \
# 0         2Y Communications Engineering      NaN         NaN
# 1             6K Hyperspace (M) Sdn Bhd      NaN         NaN
# 2              AFA Technologies Sdn Bhd      NaN         NaN
# 3  AWETEX ENGINEERING & TRADING SDN BHD      NaN         NaN
# 4            Advenxus Solutions Sdn Bhd      NaN         NaN
#
#              Company Email  Contact Person  \
# 0                      NaN             NaN
# 1  mt.lim@interstella.tech    Lim Meng Tin
# 2      lam.wh@afa-tech.com    Lam Wen Haur
# 3                      NaN             NaN
# 4    sf.chong@advenxus.com  Chong Sin Fatt
#
#                              Position  FET  FCA
# 0                                 NaN    1    0
# 1   Senior Mechanical Design Engineer    1    0
# 2                   Assistant Manager    1    0
# 3                                 NaN    1    0
# 4                    Service Engineer    1    0

# %%
# specific_df_drop_2
# Save the updated DataFrame to a CSV file
output_csv_path = 'new_dataframe.csv'
new_df.to_csv(output_csv_path, index=False)

print(f"New DataFrame saved to '{output_csv_path}'")
# Out:
# New DataFrame saved to 'new_dataframe.csv'

# %%
df = pd.read_csv("new_dataframe.csv")

output_csv_path = '10_8_combined_dataframe.csv'
df.to_csv(output_csv_path, index=False)

print(f"New DataFrame saved to '{output_csv_path}'")
# Out:
# New DataFrame saved to '10_8_combined_dataframe.csv'
